# %% [markdown]
# <a href="https://colab.research.google.com/github/yg36/LangGraph-Learnings/blob/main/LangGraph_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import List, TypedDict
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
  values: List[int]
  name : str
  result: str

# %%
def process_values(state: AgentState):
  """"This function handles multiple inputs"""
  print(state)
  state["result"] = f"Hi there {state["name"]}! Sume of values is {sum(state["values"])}."

  print(state)
  return state

# %%
graph = StateGraph(AgentState)

graph.add_node("processor", process_values)
graph.set_entry_point("processor")
graph.set_finish_point("processor")

app = graph.compile()

# %%
result = app.invoke({"values": [3,4], "name": "YG"})
# Out:
# {'values': [3, 4], 'name': 'YG'}
# {'values': [3, 4], 'name': 'YG', 'result': 'Hi there YG! Sume of values is 7.'}

# %%
result["result"]
# Out:
# 'Hi there YG! Sume of values is 7.'

# %%
result
# Out:
# {'values': [3, 4], 'name': 'YG', 'result': 'Hi there YG! Sume of values is 7.'}
